# %%
from sys import platform
import os
import re

from anki import Collection

import zhon.pinyin
import zhon.hanzi

from pinyin import *
from pinyin.chinese_master import *
# Out:
# Failed to import Anki modules

# %%
if platform == 'darwin':
    anki_path = '/Users/ericahn/Library/Application Support/'
elif platform.startswith('linux'):
    anki_path = '/home/eahn/.local/share/'
try:
    closed = len(col.findCards('deck:Mandarin')) == 0
    if not closed:
        print('Already open!')
    else:
        col = Collection(os.path.join(anki_path, 'Anki2', 'Eric', 'collection.anki2'))
        print('Reoponed')
except:
    col = Collection(os.path.join(anki_path, 'Anki2', 'Eric', 'collection.anki2'))
    print('Opened')
# Out:
# Opened

# %%
cm = ChineseMaster(col, module_path)

# %%
stage = cm.stage_match_fallback('Mandarin::Grammar Wiki',
                                'Chinese Grammar Wiki',
                                '中文',
                                'Pinyin',
                                'blank',
                                'blank')
# Out:
# How to combine? a=[，], b=[. ]
#
# How to combine? a=[，], b=[ ]
#
# How to combine? a=[，], b=[. ]
#
# How to combine? a=[，], b=[ ]
#
# How to combine? a=[！], b=[.]
#
# How to combine? a=[，], b=[ , ]
#
# How to combine? a=[？], b=[i?]
#
# How to combine? a=[，], b=[​, ]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[。], b=[!]
#
# How to combine? a=[，], b=[ , ]
#
# How to combine? a=["。], b=[."]
#
# How to combine? a=[？], b=[.]
#
# How to combine? a=[？], b=[.]
#
# How to combine? a=[，], b=[ , ]
#
# How to combine? a=[，], b=[,]
#
# How to combine? a=[！], b=[, ]
#
# How to combine? a=[！], b=[ ]
#
# How to combine? a=[！], b=[.]
#
# How to combine? a=["。], b=[."]
#
# How to combine? a=[，], b=[.]
#
# How to combine? a=[！], b=[.]
#
# How to combine? a=[，], b=[,]
#
# How to combine? a=[，], b=[,]
#
# How to combine? a=[？], b=[.]
#
# How to combine? a=[，], b=[,]
#
# How to combine? a=[；], b=[, ]
#
# How to combine? a=[；], b=[ ]
#
# How to combine? a=[Wi-Fi，], b=[ Wi-Fi, ]

# %%
stage['match', ('blank',)]
# Out:
# [[<anki.notes.Note at 0x7fef11bb1fd0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef059237b8>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '现在', 'xiàn zài'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef059237f0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef059236d8>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05923b00>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '北京', 'Běi jīng'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '房子', 'fáng zi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef059238d0>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05923ba8>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '朋友', 'péng you'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05923cf8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, ' ', None),
#    (True, '现在', 'xiàn zài'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef38d7a588>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '电脑', 'diàn nǎo'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05923cc0>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '周末', 'zhōu mò'),
#    (False, ' ', None),
#    (True, '你们', 'nǐ men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '时间', 'shí jiān'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05923ef0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05923a58>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05923e10>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '车', 'chē'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cd080>,
#   [(True, '老板', 'Lǎo bǎn'),
#    (False, ' ', None),
#    (True, '现在', 'xiàn zài'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '时间', 'shí jiān'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05923d68>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, '，', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '老公', 'lǎo gōng'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd390>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd0b8>,
#   [(True, '明天', 'Míng tiān'),
#    (False, ' ', None),
#    (True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '可以', 'kě yǐ'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd358>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '用', 'yòng'),
#    (False, ' wiki ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cd668>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '冰水', 'bīng shuǐ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd710>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '爱', 'ài'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd6a0>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '美国', 'Měi guó'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cd8d0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '太太', 'tài tai'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '肉', 'ròu'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd978>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, ' ', None),
#    (True, '中国', 'Zhōng guó'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cda58>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '她', 'tā'),
#    (False, ' ', None),
#    (True, '老公', 'lǎo gōng'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, '  ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cdac8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cda90>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '学生', 'xué sheng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cdc50>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '儿子', 'ér zi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cdbe0>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '法国', 'Fǎ guó'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cddd8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '学', 'xué'),
#    (False, ' ', None),
#    (True, '中文', 'Zhōng wén'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cd908>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '会', 'huì'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cdf60>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '饺子', 'jiǎo zi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058cdba8>,
#   [(True, '孩子', 'Hái zi'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, '  ', None),
#    (True, '可以', 'kě yǐ'),
#    (False, ' ', None),
#    (True, '喝酒', 'hē jiǔ'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058cdc88>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, '  ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '来', 'lái'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05875198>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '觉得', 'jué de'),
#    (False, ' ', None),
#    (True, '这个', 'zhè ge'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058752e8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875390>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '知道', 'zhī dào'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875470>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '没有', 'méi yǒu'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875128>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '来', 'lái'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058755f8>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '高', 'gāo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058756a0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, '  ', None),
#    (True, '胖', 'pàng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875748>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, '  ', None),
#    (True, '帅', 'shuài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875860>,
#   [(True, '湖南', 'Hú nán'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '辣', 'là'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058758d0>,
#   [(True, '这', 'Zhè'),
#    (False, ' ', None),
#    (True, '种', 'zhǒng'),
#    (False, ' ', None),
#    (True, '酒', 'jiǔ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '好喝', 'hǎo hē'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef058759b0>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '地方', 'dì fang'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '漂亮', 'piào liang'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875ac8>,
#   [(True, '昨天', 'Zuó tiān'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '冷', 'lěng'),
#    (False, '，', None),
#    (True, '今天', 'jīn tiān'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '冷', 'lěng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875908>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '生气', 'shēng qì'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '？', None),
#    (True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '生气', 'shēng qì'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef05875828>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '麻烦', 'má fan'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875cf8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '觉得', 'jué de'),
#    (False, ' ', None),
#    (True, '这个', 'zhè ge'),
#    (False, ' ', None),
#    (True, '餐厅', 'cān tīng'),
#    (False, ' ', None),
#    (True, '也', 'yě'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875c50>,
#   [(True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef05875c88>,
#   [(True, '老板', 'Lǎo bǎn'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, ' ', None),
#    (True, '咖啡', 'kā fēi'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '茶', 'chá'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875f28>,
#   [(True, '他', 'Tā'),
#    (False, '  ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '他', 'tā'),
#    (False, ' ', None),
#    (True, '女朋友', 'nǚ péng you'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, ' ', None),
#    (True, '中国', 'Zhōng guó'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05880080>,
#   [(True, '手机', 'Shǒu jī'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '电脑', 'diàn nǎo'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '贵', 'guì'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05875f98>,
#   [(True, '德语', 'Dé yǔ'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '法语', 'Fǎ yǔ'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '难', 'nán'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880208>,
#   [(True, '今天', 'Jīn tiān'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '明天', 'míng tiān'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '可以', 'kě yǐ'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880128>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '他', 'tā'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058803c8>,
#   [(True, '一', 'Yī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880470>,
#   [(True, '辣', 'Là'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '辣', 'là'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880240>,
#   [(True, '冰', 'Bīng'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '热', 'rè'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058805f8>,
#   [(True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '北京', 'Běi jīng'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880550>,
#   [(True, '这', 'Zhè'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '水', 'shuǐ'),
#    (False, '  ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '酒', 'jiǔ'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880710>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '美国', 'Měi guó'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, '  ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '英国', 'Yīng guó'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef05880390>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '喜欢', 'xǐ huan'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, '  ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058804a8>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '喝', 'hē'),
#    (False, ' ', None),
#    (True, '茶', 'chá'),
#    (False, ' ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '咖啡', 'kā fēi'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058802e8>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '中国', 'Zhōng guó'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, '  ', None),
#    (True, '还是', 'hái shì'),
#    (False, ' ', None),
#    (True, '法国', 'Fǎ guó'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef058807b8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '儿子', 'ér zi'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '岁', 'suì'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05880dd8>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '岁', 'suì'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05880eb8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '儿子', 'ér zi'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '岁', 'suì'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef05880f98>,
#   [(True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef05880be0>,
#   [(True, '四', 'sì'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '朋友', 'péng you'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef05880e80>,
#   [(True, '三', 'sān'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '苹果', 'Píng guǒ'),
#    (False, ' ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef05880f60>,
#   [(True, '五', 'wǔ'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '星期', 'xīng qī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0588f1d0>,
#   [(True, '六', 'liù'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '月', 'yuè'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0588f0f0>,
#   [(True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, '  ', None),
#    (True, '老婆', 'lǎo po'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0588f3c8>,
#   [(True, '十', 'shí'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '男人', 'nán rén'),
#    (False, '，', None),
#    (True, '七', 'qī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '傻', 'shǎ'),
#    (False, '，', None),
#    (True, '八', 'bā'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '坏', 'huài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0588f358>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '老外', 'lǎo wài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0588f550>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '儿子', 'ér zi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0588f5f8>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0588f400>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '包子', 'bāo zi'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0588f780>,
#   [(True, '老师', 'Lǎo shī'),
#    (False, '，', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e128>,
#   [(True, '今天', 'Jīn tiān'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '星期一', 'Xīng qī yī'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0589e320>,
#   [(True, '明天', 'Míng tiān'),
#    (False, ' ', None),
#    (True, '星期五', 'Xīng qī wǔ'),
#    (False, '，', None),
#    (True, '太', 'tài'),
#    (False, ' ', None),
#    (True, '高兴', 'gāo xìng'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e438>,
#   [(True, '星期三', 'Xīng qī sān'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e518>,
#   [(True, '星期', 'Xīng qī'),
#    (False, "'", None),
#    (True, '二', 'èr'),
#    (False, ' ', None),
#    (True, '早上', 'zǎo shang'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '忙', 'máng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e5f8>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '星期天', 'Xīng qī tiān'),
#    (False, ' ', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '做', 'zuò'),
#    (False, ' ', None),
#    (True, '什么', 'shén me'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0589e550>,
#   [(True, '上', 'Shàng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '星期五', 'Xīng qī wǔ'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '跟', 'gēn'),
#    (False, ' ', None),
#    (True, '他', 'tā'),
#    (False, ' ', None),
#    (True, '见面', 'jiàn miàn'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e630>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '星期三', 'Xīng qī sān'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '空', 'kòng'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0589e898>,
#   [(True, '下', 'Xià'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '星期四', 'Xīng qī sì'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '生日', 'shēng rì'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e940>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '星期五', 'Xīng qī wǔ'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, ' ', None),
#    (True, '酒吧', 'jiǔ bā'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e400>,
#   [(True, '星期六', 'Xīng qī liù'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '星期天', 'Xīng qī tiān'),
#    (False, ' ', None),
#    (True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '上班', 'shàng bān'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0589e9e8>,
#   [(True, '九', 'jiǔ'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589eb70>,
#   [(True, '上午', 'shàng wǔ'),
#    (False, ' ', None),
#    (True, '七', 'qī'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589e278>,
#   [(True, '下午', 'xià wǔ'),
#    (False, ' ', None),
#    (True, '四', 'sì'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589e860>,
#   [(True, '中午', 'zhōng wǔ'),
#    (False, ' ', None),
#    (True, '十', 'shí'),
#    (False, "'", None),
#    (True, '二', 'èr'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589eb00>,
#   [(True, '明天', 'míng tiān'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '七', 'qī'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589ed68>,
#   [(True, '星期三', 'Xīng qī sān'),
#    (False, ' ', None),
#    (True, '上午', 'shàng wǔ'),
#    (False, ' ', None),
#    (True, '九', 'jiǔ'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589eef0>,
#   [(True, '五', 'wǔ'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589e8d0>,
#   [(True, '下午', 'xià wǔ'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0589ef28>,
#   [(True, '星期天', 'Xīng qī tiān'),
#    (False, ' ', None),
#    (True, '上午', 'shàng wǔ'),
#    (False, ' ', None),
#    (True, '十', 'shí'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d080>,
#   [(True, '昨天', 'zuó tiān'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '七', 'qī'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d1d0>,
#   [(True, '今天', 'jīn tiān'),
#    (False, ' ', None),
#    (True, '下午', 'xià wǔ'),
#    (False, ' ', None),
#    (True, '四', 'sì'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '半', 'bàn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d0b8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '大', 'dà'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d358>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '哥哥', 'gē ge'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '高', 'gāo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d438>,
#   [(True, '这', 'Zhè'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '女朋友', 'nǚ péng you'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d4a8>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '漂亮', 'piào liang'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d550>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '学校', 'xué xiào'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '大', 'dà'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d160>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '公司', 'gōng sī'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '北京', 'Běi jīng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d320>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '帅', 'shuài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d6a0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '儿子', 'ér zi'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '有名', 'yǒu míng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d710>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '女', 'nǚ'),
#    (False, "'", None),
#    (True, '儿', 'ér'),
#    (False, ' ', None),
#    (True, '会', 'huì'),
#    (False, ' ', None),
#    (True, '说', 'shuō'),
#    (False, ' ', None),
#    (True, '英语', 'Yīng yǔ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d748>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '公司', 'gōng sī'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '老板', 'lǎo bǎn'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0582d470>,
#   [(True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d780>,
#   [(True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, '  ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d940>,
#   [(True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d9b0>,
#   [(True, '他们', 'tā men'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '东西', 'dōng xi'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d7f0>,
#   [(True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '车', 'chē'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d9e8>,
#   [(True, '你们', 'nǐ men'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '菜', 'cài'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582dbe0>,
#   [(True, '北京', 'Běi jīng'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '空气', 'kōng qì'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582dc88>,
#   [(True, '公司', 'gōng sī'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '老板', 'lǎo bǎn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582dd30>,
#   [(True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, '  ', None),
#    (True, '天气', 'tiān qì'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582ddd8>,
#   [(True, '老师', 'lǎo shī'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '朋友', 'péng you'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef0582d908>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, '，', None),
#    (True, '那个', 'nà ge'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0582df60>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '用', 'yòng'),
#    (False, ' ', None),
#    (True, '中文', 'Zhōng wén'),
#    (False, ' ', None),
#    (True, '怎么', 'zěn me'),
#    (False, ' ', None),
#    (True, '说', 'shuō'),
#    (False, '？', None),
#    (True, '那个', 'Nà ge'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0582df28>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, '', None),
#    (True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0582deb8>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, '，', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e208>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '哥哥', 'gē ge'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, '', None),
#    (True, '弟弟', 'Dì di'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0582dc50>,
#   [(True, '北京', 'Běi jīng'),
#    (False, ' ', None),
#    (True, '下雨', 'xià yǔ'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e400>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '现在', 'xiàn zài'),
#    (False, ' ', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '出去', 'chū qù'),
#    (False, '。', None),
#    (True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e4e0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '知道', 'zhī dào'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '会', 'huì'),
#    (False, ' ', None),
#    (True, '说', 'shuō'),
#    (False, ' ', None),
#    (True, '中文', 'Zhōng wén'),
#    (False, '。', None),
#    (True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '老公', 'lǎo gōng'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e438>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '周末', 'zhōu mò'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, ' ', None),
#    (True, '酒吧', 'jiǔ bā'),
#    (False, '。', None),
#    (True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e518>,
#   [(True, '今天', 'Jīn tiān'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '空', 'kòng'),
#    (False, '？', None),
#    (True, '明天', 'Míng tiān'),
#    (False, ' ', None),
#    (True, '晚上', 'wǎn shang'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e588>,
#   [(True, '钱', 'Qián'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e710>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e780>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, ' ', None),
#    (True, '呢', 'ne'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583e2e8>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '走', 'zǒu'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e5f8>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '说', 'shuō'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e6a0>,
#   [(True, '快', 'Kuài'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e390>,
#   [(True, '给', 'Gěi'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e908>,
#   [(True, '喝', 'Hē'),
#    (False, ' ', None),
#    (True, '水', 'shuǐ'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e5c0>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, ' ', None),
#    (True, '香港', 'Xiāng gǎng'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e828>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '六', 'liù'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0583eb38>,
#   [(True, '休息', 'Xiū xi'),
#    (False, ' ', None),
#    (True, '一下', 'yī xià'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583ea20>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '结婚', 'jié hūn'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583eac8>,
#   [(True, '老板', 'Lǎo bǎn'),
#    (False, '，', None),
#    (True, '便宜', 'pián yi'),
#    (False, ' ', None),
#    (True, '一点', 'yī diǎn'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583ee80>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '上海', 'Shàng hǎi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583ef28>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '英国', 'Yīng guó'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583eba8>,
#   [(True, '老板', 'Lǎo bǎn'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '外面', 'wài miàn'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583edd8>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '学校', 'xué xiào'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0583e7f0>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '现在', 'xiàn zài'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, '  ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f128>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '公司', 'gōng sī'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f278>,
#   [(True, '老师', 'Lǎo shī'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, '  ', None),
#    (True, '办公室', 'bàn gōng shì'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f3c8>,
#   [(True, '谁', 'Shéi'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '楼上', 'lóu shàng'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f4a8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '和', 'hé'),
#    (False, ' ', None),
#    (True, '朋友', 'péng you'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '酒吧', 'jiǔ bā'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f550>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '多', 'duō'),
#    (False, ' ', None),
#    (True, '小', 'xiǎo'),
#    (False, ' ', None),
#    (True, '狗', 'gǒu'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f5c0>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '学校', 'xué xiào'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '多', 'duō'),
#    (False, ' ', None),
#    (True, '帅哥', 'shuài gē'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f7b8>,
#   [(True, '日本', 'Rì běn'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '多', 'duō'),
#    (False, ' ', None),
#    (True, '中国', 'Zhōng guó'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f6a0>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '酒吧', 'jiǔ bā'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '多', 'duō'),
#    (False, ' ', None),
#    (True, '美女', 'měi nǚ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f7f0>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '牛奶', 'niú nǎi'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f400>,
#   [(True, '这里', 'Zhè lǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584f940>,
#   [(True, '房间', 'Fáng jiān'),
#    (False, ' ', None),
#    (True, '里', 'lǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584fb38>,
#   [(True, '杯子', 'Bēi zi'),
#    (False, ' ', None),
#    (True, '里', 'lǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '水', 'shuǐ'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584fc50>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, ' ', None),
#    (True, '里', 'lǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '号码', 'hào mǎ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584fcf8>,
#   [(True, '现在', 'Xiàn zài'),
#    (False, '  ', None),
#    (True, '办公室', 'bàn gōng shì'),
#    (False, ' ', None),
#    (True, '里', 'lǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '人', 'rén'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584f710>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584fef0>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '房子', 'fáng zi'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0584fd30>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '车', 'chē'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0584ffd0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '女朋友', 'nǚ péng you'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0585f0f0>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '三', 'sān'),
#    (False, ' ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '女', 'nǚ'),
#    (False, "'", None),
#    (True, '儿', 'ér'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585f208>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '家', 'jiā'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '两', 'liǎng'),
#    (False, '  ', None),
#    (True, '个', 'gè'),
#    (False, ' ', None),
#    (True, '公司', 'gōng sī'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585f320>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '百', 'bǎi'),
#    (False, ' ', None),
#    (True, '块', 'kuài'),
#    (False, ' ', None),
#    (True, '钱', 'qián'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0585f438>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '爸爸', 'bà ba'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, ' ', None),
#    (True, '工作', 'gōng zuò'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585f630>,
#   [(True, '今天', 'Jīn tiān'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '有', 'yǒu'),
#    (False, '  ', None),
#    (True, '课', 'kè'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0585f7f0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '叫', 'jiào'),
#    (False, ' ', None),
#    (True, '李', 'Lǐ'),
#    (False, ' ', None),
#    (True, '小龙', 'Xiǎo lóng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585f4e0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '哥哥', 'gē ge'),
#    (False, ' ', None),
#    (True, '叫', 'jiào'),
#    (False, ' ', None),
#    (True, '老', 'Lǎo'),
#    (False, ' ', None),
#    (True, '马', 'Mǎ'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585f978>,
#   [(True, '那个', 'Nà ge'),
#    (False, ' ', None),
#    (True, '叫', 'jiào'),
#    (False, ' ', None),
#    (True, '什么', 'shén me'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0585fcc0>,
#   [(True, '这个', 'Zhè ge'),
#    (False, ' ', None),
#    (True, '地方', 'dì fang'),
#    (False, ' ', None),
#    (True, '叫', 'jiào'),
#    (False, ' ', None),
#    (True, '外滩', 'Wài tān'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0585ff98>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '叫', 'jiào'),
#    (False, ' ', None),
#    (True, '什么', 'shén me'),
# ...
#    (True, '没', 'Méi'),
#    (False, ' ', None),
#    (True, '见', 'jiàn'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '漂亮', 'piào liang'),
#    (False, ' ', None),
#    (True, '姑娘', 'gū niang'),
#    (False, ' ', None),
#    (True, '啊', 'a'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef0551afd0>,
#   [(True, '这', 'Zhè'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '太', 'tài'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0551a978>,
#   [(True, '算', 'Suàn'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef0551ad30>,
#   [(True, '应该', 'Yīng gāi'),
#    (False, ' ', None),
#    (True, '是', 'shì'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae0b8>,
#   [(True, '钱', 'Qián'),
#    (False, ' ', None),
#    (True, '太', 'tài'),
#    (False, ' ', None),
#    (True, '少', 'shǎo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae208>,
#   [(True, '再', 'Zài'),
#    (False, ' ', None),
#    (True, '等', 'děng'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '等', 'děng'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae2e8>,
#   [(True, '太', 'Tài'),
#    (False, ' ', None),
#    (True, '晚', 'wǎn'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '，', None),
#    (True, '不要', 'bù yào'),
#    (False, ' ', None),
#    (True, '走', 'zǒu'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae438>,
#   [(True, '你们', 'Nǐ men'),
#    (False, ' ', None),
#    (True, '早', 'zǎo'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '来', 'lái'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae518>,
#   [(True, '快', 'Kuài'),
#    (False, ' ', None),
#    (True, '点', 'diǎn'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '，', None),
#    (True, '要', 'yào'),
#    (False, ' ', None),
#    (True, '迟到', 'chí dào'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae470>,
#   [(True, '太', 'Tài'),
#    (False, ' ', None),
#    (True, '贵', 'guì'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '，', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '买', 'mǎi'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae6d8>,
#   [(True, '那个', 'Nà ge'),
#    (False, ' ', None),
#    (True, '地方', 'dì fang'),
#    (False, ' ', None),
#    (True, '太', 'tài'),
#    (False, ' ', None),
#    (True, '远', 'yuǎn'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吧', 'ba'),
#    (False, '，', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '想', 'xiǎng'),
#    (False, ' ', None),
#    (True, '去', 'qù'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054ae4a8>,
#   [(True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '李', 'Lǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '房子', 'fáng zi'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae898>,
#   [(True, '红色', 'hóng sè'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '自行车', 'zì xíng chē'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae940>,
#   [(True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '手机', 'shǒu jī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae9e8>,
#   [(True, '我们', 'wǒ men'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aeac8>,
#   [(True, '漂亮', 'piào liang'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '衣服', 'yī fu'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae5f8>,
#   [(True, '热闹', 'rè nao'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '酒吧', 'jiǔ bā'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aeb00>,
#   [(True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, '  ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '公司', 'gōng sī'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aeba8>,
#   [(True, '做', 'zuò'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aec18>,
#   [(True, '说', 'shuō'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '太', 'tài'),
#    (False, ' ', None),
#    (True, '快', 'kuài'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aee48>,
#   [(True, '玩', 'wán'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '开心', 'kāi xīn'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae978>,
#   [(True, '开', 'kāi'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '快', 'kuài'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aecf8>,
#   [(True, '住', 'zhù'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '很', 'hěn'),
#    (False, ' ', None),
#    (True, '舒服', 'shū fu'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054aee10>,
#   [(True, '生气', 'shēng qì'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '说', 'shuō'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054ae5c0>,
#   [(True, '开心', 'kāi xīn'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '笑', 'xiào'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054c0080>,
#   [(True, '慢慢', 'màn màn'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '走', 'zǒu'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054c0198>,
#   [(True, '伤心', 'shāng xīn'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '哭', 'kū'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054c00b8>,
#   [(True, '认真', 'rèn zhēn'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '听', 'tīng'),
#    (False, '', None)]],
#  [<anki.notes.Note at 0x7fef054c01d0>,
#   [(True, '今天', 'Jīn tiān'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '作业', 'zuò yè'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '做', 'zuò'),
#    (False, ' ', None),
#    (True, '得', 'de'),
#    (False, ' ', None),
#    (True, '不', 'bù'),
#    (False, ' ', None),
#    (True, '好', 'hǎo'),
#    (False, '，', None),
#    (True, '因为', 'yīn wèi'),
#    (False, ' ', None),
#    (True, '你', 'nǐ'),
#    (False, ' ', None),
#    (True, '没', 'méi'),
#    (False, ' ', None),
#    (True, '认真', 'rèn zhēn'),
#    (False, ' ', None),
#    (True, '地', 'de'),
#    (False, ' ', None),
#    (True, '听课', 'tīng kè'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0470>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0550>,
#   [(True, '牙', 'Yá'),
#    (False, ' ', None),
#    (True, '刷', 'shuā'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0630>,
#   [(True, '洗', 'Xǐ'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0710>,
#   [(True, '我们', 'Wǒ men'),
#    (False, ' ', None),
#    (True, '看', 'kàn'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0828>,
#   [(True, '他们', 'Tā men'),
#    (False, ' ', None),
#    (True, '见', 'jiàn'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0908>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '饭', 'fàn'),
#    (False, '  ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef054c06d8>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '刷', 'shuā'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '牙', 'yá'),
#    (False, '  ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c07f0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '洗', 'xǐ'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '澡', 'zǎo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c08d0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '给', 'gěi'),
#    (False, ' ', None),
#    (True, '他', 'tā'),
#    (False, ' ', None),
#    (True, '打', 'dǎ'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '电话', 'diàn huà'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0cf8>,
#   [(True, '客户', 'Kè hù'),
#    (False, ' ', None),
#    (True, '看', 'kàn'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, '  ', None),
#    (True, '合同', 'hé tong'),
#    (False, '  ', None),
#    (True, '了', 'le'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef054c09b0>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '已经', 'yǐ jīng'),
#    (False, '  ', None),
#    (True, '吃', 'chī'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '饭', 'fàn'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0f60>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '已经', 'yǐ jīng'),
#    (False, '  ', None),
#    (True, '刷', 'shuā'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '牙', 'yá'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054c0f98>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '已经', 'yǐ jīng'),
#    (False, '  ', None),
#    (True, '洗', 'xǐ'),
#    (False, ' ', None),
#    (True, '过', 'guo'),
#    (False, ' ', None),
#    (True, '澡', 'zǎo'),
#    (False, ' ', None),
#    (True, '了', 'le'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf438>,
#   [(True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '李', 'Lǐ'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '张', 'Zhāng'),
#    (False, ' ', None),
#    (True, '高', 'gāo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf5c0>,
#   [(True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '张', 'Zhāng'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '李', 'Lǐ'),
#    (False, ' ', None),
#    (True, '矮', 'ǎi'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf6a0>,
#   [(True, '他', 'Tā'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '老师', 'lǎo shī'),
#    (False, ' ', None),
#    (True, '聪明', 'cōng ming'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf390>,
#   [(True, '上海', 'Shàng hǎi'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '纽约', 'Niǔ yuē'),
#    (False, ' ', None),
#    (True, '大', 'dà'),
#    (False, ' ', None),
#    (True, '吗', 'ma'),
#    (False, '？', None)]],
#  [<anki.notes.Note at 0x7fef054cf7b8>,
#   [(True, '她', 'Tā'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '她', 'tā'),
#    (False, ' ', None),
#    (True, '妈妈', 'mā ma'),
#    (False, '  ', None),
#    (True, '漂亮', 'piào liang'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf8d0>,
#   [(True, '星巴克', 'Xīng bā kè'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '咖啡', 'kā fēi'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '这里', 'zhè lǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '咖啡', 'kā fēi'),
#    (False, ' ', None),
#    (True, '贵', 'guì'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf668>,
#   [(True, '地铁', 'Dì tiě'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, '  ', None),
#    (True, '公交车', 'gōng jiāo chē'),
#    (False, ' ', None),
#    (True, '方便', 'fāng biàn'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf748>,
#   [(True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '李', 'Lǐ'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '小', 'Xiǎo'),
#    (False, ' ', None),
#    (True, '张', 'Zhāng'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '高', 'gāo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cf7f0>,
#   [(True, '我', 'Wǒ'),
#    (False, ' ', None),
#    (True, '哥哥', 'gē ge'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '高', 'gāo'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cfb38>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '男朋友', 'nán péng you'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '帅', 'shuài'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cfba8>,
#   [(True, '这里', 'Zhè lǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '冬天', 'dōng tiān'),
#    (False, '  ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '纽约', 'Niǔ yuē'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '冬天', 'dōng tiān'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '冷', 'lěng'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cfc50>,
#   [(True, '中文', 'Zhōng wén'),
#    (False, ' ', None),
#    (True, '语法', 'yǔ fǎ'),
#    (False, '  ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '汉字', 'Hàn zì'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '难', 'nán'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cfbe0>,
#   [(True, '你', 'Nǐ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, ' ', None),
#    (True, '比', 'bǐ'),
#    (False, ' ', None),
#    (True, '我', 'wǒ'),
#    (False, ' ', None),
#    (True, '的', 'de'),
#    (False, ' ', None),
#    (True, '问题', 'wèn tí'),
#    (False, ' ', None),
#    (True, '更', 'gèng'),
#    (False, ' ', None),
#    (True, '麻烦', 'má fan'),
#    (False, '。', None)]],
#  [<anki.notes.Note at 0x7fef054cfdd8>,
#   [(True, '从', 'Cóng'),
#    (False, ' ', None),
#    (True, '一', 'yī'),
#    (False, ' ', None),
#    (True, '号', 'hào'),
#    (False, ' ', None),
#    (True, '到', 'dào'),
#    (False, ' ', None),
#    (True, '五', 'wǔ'),
#    (False, ' ', None),
#    (True, '号', 'hào'),
#    (False, ' ', None),
#    (True, '都', 'dōu'),
#    (False, ' ', None),
#    (True, '在', 'zài'),
#    (False, ' ', None),
#    (True, '下雨', 'xià yǔ'),
#    (False, '。', None)]],
#  ...]
